# %%
#Get live market, approx 1.5 seconds.

# %%
# Raw Package
import numpy as np
import pandas as pd

# %%
#Data Source
import yfinance as yf

# %%
#Data viz
import plotly.graph_objs as go

# %% [markdown]
# # How to get live market data per minutes

# %%
data = yf.download(tickers='UBER', period='5d', interval='15m')
#Interval required 1 minute
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
# Datetime
# 2021-10-18 09:30:00-04:00  47.680000  47.950001  47.320000  47.770000
# 2021-10-18 09:45:00-04:00  47.760101  47.820000  47.320301  47.539501
# 2021-10-18 10:00:00-04:00  47.545399  47.660000  47.360001  47.490101
# 2021-10-18 10:15:00-04:00  47.494999  47.543800  47.404999  47.445000
# 2021-10-18 10:30:00-04:00  47.445801  47.509998  47.084999  47.130001
# ...                              ...        ...        ...        ...
# 2021-10-22 14:45:00-04:00  45.514999  45.560001  45.415001  45.509998
# 2021-10-22 15:00:00-04:00  45.509998  45.544998  45.410000  45.455002
# 2021-10-22 15:15:00-04:00  45.455002  45.514999  45.404999  45.500000
# 2021-10-22 15:30:00-04:00  45.505001  45.590000  45.453999  45.505001
# 2021-10-22 15:45:00-04:00  45.505001  45.669998  45.490002  45.509998
#
#                            Adj Close   Volume
# ...

# %%
data = yf.download(tickers='UBER', period='1d', interval='1m')
#Interval required 1 minute

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles
fig.update_layout(
    title='Uber live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Multiple shares

# %%
listshare = ['UBER','MSFT','AMZN']

data = yf.download(tickers=listshare, period='5d', interval='15m')
#Interval required 1 minute
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                              Adj Close                               Close  \
#                                   AMZN        MSFT       UBER         AMZN
# Datetime
# 2021-10-18 09:30:00-04:00  3419.320312  304.920807  47.770000  3419.320312
# 2021-10-18 09:45:00-04:00  3420.050049  304.480011  47.539501  3420.050049
# 2021-10-18 10:00:00-04:00  3420.000000  304.890015  47.490101  3420.000000
# 2021-10-18 10:15:00-04:00  3409.300049  303.920013  47.445000  3409.300049
# 2021-10-18 10:30:00-04:00  3406.360107  303.720001  47.130001  3406.360107
# ...                                ...         ...        ...          ...
# 2021-10-22 14:45:00-04:00  3346.770020  309.540009  45.509998  3346.770020
# 2021-10-22 15:00:00-04:00  3344.000000  309.220001  45.455002  3344.000000
# 2021-10-22 15:15:00-04:00  3337.435059  309.109985  45.500000  3337.435059
# ...
